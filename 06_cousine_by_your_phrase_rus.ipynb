# %%
import numpy as np  
import pandas as pd
import re  
import scipy
import nltk

from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer  
from pymystem3 import Mystem
from scipy.spatial import distance 

nltk.download('wordnet')
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\v.kozlovskiy\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\v.kozlovskiy\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\v.kozlovskiy\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
path = 'C:/Users/v.kozlovskiy/Desktop/DATAS/from_aug24/_ekklesiat_wc_and_other/to_git/'

# %%
m = Mystem() # lemmatizer for russian words

# %%
# open prepared file
text_df = pd.read_excel(path + 'text_for_analysis_rus.xlsx')
original = list(text_df['original'])
text = list(text_df['processed'])
text
# Out:
# ['слово екклесиаст сын давидова царь в иерусалим',
#  'суета суета сказать екклесиаст суета суета все суета',
#  'что польза человек от весь труд его который трудиться он под солнце',
#  'род проходить и род приходить а земля пребывать во веко',
#  'восходить солнце и заходить солнце и спешить к место свой где оно восходить',
#  'идти ветер к юг и переходить к север кружиться кружиться на ход свой и возвращаться ветер на круг свой',
#  'весь река течь в море но море не переполняться к тот место откуда река течь они возвращаться чтобы опять течь',
#  'весь вещь в труд не мочь человек пересказывать все не насыщаться око зрение не наполняться ухо слушание',
#  'что быть то и быть и что делаться то и быть делаться и нет ничто новый под солнце',
#  'бывать нечто о чем говорить смотреть вот это новое но это быть уже в век бывший прежде мы',
#  'нет память о прежний да и о то что быть не оставаться память у тот который быть после',
#  'я екклесиаст быть царь над израиль в иерусалим',
#  'и предавать я сердце мой то чтобы исследовать и испытывать мудрость все что делаться под небо этот тяжелый занятие давать бог сын человеческий чтобы они упражняться в немой',
#  'видеть я весь дело какой делаться под солнце и вот все суета и томление дух',
#  'кривой не мочь сделаться прямой и что нет тот нельзя считать',
#  'говорить я с сердце мой так вот я возвеличиваться и приобретать мудрость много весь который быть прежде я над иерусалим и сердце мой видеть много мудрость и знание',
#  'и предавать я сердце мой то чтобы познавать мудрость и познавать безумие и глупость узнавать что и этот томление дух',
#  'потому что во многий мудрость много печаль и кто умножать познание умножать скорбь',
#  'сказать я в сердце мой давать испытывать я ты веселие и наслаждаться добро но и это суета',
#  'о смех сказать я глупость а о веселие что оно делать',
#  'вздумать я в сердце мой услаждать вино тело мой и между то как сердце мой руководиться мудрость придерживаться и глупость доколе не увидеть что хороший для сын человеческий что должный быть бы они делать под небо в немногий день жизнь свой',
#  'я предпринимать большой дело построить себя дом посадить себя виноградник',
#  'устраивать себя сад и роща и насаждать в они всякий плодовитый дерево',
#  'сделать себя водоем для орошение из они роща произращать дерево',
#  'приобретать себя слуга и служанка и домочадец быть у я также крупный и мелкий скот быть у я много нежели у весь бывший прежде я в иерусалим',
#  'собирать себя серебро и золото и драгоценность от царь и область заводить у себя певец и певица и услаждение сын человеческий разный музыкальный орудие',
#  'и сделаться я великий и богатый много все бывший прежде я в иерусалим и мудрость мой пребыть со я',
#  'что бы глаз мой ни пожелать я не отказывать они не возбранять сердце мой никакой веселие потому что сердце мой радоваться во весь труд мой и это быть мой доля от весь труд мой',
#  'пир устраиваться для удовольствие и вино веселить жизнь а за весь отвечать серебро',
#  'даже и в мысль твой не злословить царь и в спальный комната твой не злословить богатый потому что птица небесный мочь перенести слово твой и крылатый пересказывать речь твой',
#  'отпускать хлеб твой по вода потому что по прошествие многий день опять находить он',
#  'давать часть семь и даже восемь потому что не знать какой беда быть на земля',
#  'когда облако быть полный то они проливать на земля дождь и если упасть дерево на юг или на север то оно там и оставаться куда упасть',
#  'кто наблюдать ветер тот не сеять и кто смотреть на облако тот не жать',
#  'как ты не знать путь ветер и то как образовываться кость во чрево беременный так не мочь знать дело бог который делать весь',
#  'утро сей семя твой и вечер не давать отдых рука твой потому что ты не знать то или другой быть удачный или то и другой равный хорошо быть',
#  'сладкий свет и приятно для глаз видеть солнце',
#  'если человек проживать и много год то пусть веселиться он в продолжение весь они и пусть помнить о день темный который быть много все что быть суета',
#  'веселиться юноша в юность твой и да вкушать сердце твой радость во день юность твой и ходить по путь сердце твой и по видение око твой только знать что за весь это бог приводить ты на суд',
#  'и удалять печаль от сердце твой и уклонять злой от тело твой потому что детство и юность суета',
#  'и помнить создатель твой в день юность твой доколе не приходить тяжелый день и не наступать год о который ты быть говорить нет я удовольствие в они',
#  'доколе не померкнуть солнце и свет и луна и звезда и не находить новый туча вслед за дождь',
#  'в тот день когда задрожать стеречь дом и сгибаться муж сила и переставать молоть молоть потому что их немного оставаться и помрачаться смотреть в окно',
#  'и запираться быть дверь на улица когда замолкать звук жернов и быть вставать человек по крик петух и замолкать дщерь пение',
#  'и высота быть они страшный и на дорога ужас и зацветать миндаль и отяжелеть кузнечик и рассыпаться каперс ибо отходить человек в вечный дом свой и готовый окружать он по улица плакальщица',
#  'доколе не порваться серебряный цепочка и не разрываться золотой повязка и не разбиваться кувшин у источник и не обрушиваться колесо над колодезь',
#  'и возвращаться прах в земля чем он и быть а дух возвращаться к бог который давать он',
#  'суета суета сказать екклесиаст все суета',
#  'кроме то что екклесиаст быть мудрый он учить еще народ знание он весь испытывать исследовать и составлять много притча',
#  'стараться екклесиаст приискивать изящный изречение и слово истина написать они верно',
#  'слово мудрый как игла и как вбивать гвоздь и составитель они от единый пастырь',
#  'а что сверх весь это сын мой то беречься составлять много книга конец не быть и много читать утомительно для тело',
#  'выслушивать сущность все бояться бог и заповедь его соблюдать потому что в это все для человек',
#  'ибо всякий дело бог приводить на суд и все тайный хорошо ли оно или худо']

# %%
def matrix_by_text(text):
    # preprocessing like before making wordcloud
    russian_stopwords = stopwords.words("russian")
    russian_stopwords.extend(['это', 'все', 'вс'])
    english_stopwords = stopwords.words("english")
    union = ' '.join(text)
    text_tokens = word_tokenize(union)
    text_tokens = [token.strip() for token in text_tokens if token not in russian_stopwords]
    
    # select unique tokens
    uniq_tokens = pd.Series(text_tokens).unique()

    # matrix for analysis in first dimension strings in text in second unique tokens
    matrix = np.zeros((len(text), len(uniq_tokens)))
    print('Number of strings in text:', len(text))
    print('Number of tokens in text:', len(text_tokens))
    print('Number of unique tokens in text:', len(uniq_tokens))
    print('Matrix shape:', matrix.shape)
    
    # cycle for fill the matrix (if corresponding token is in sentence 1, if no 0)
    for sentence in range(len(text)):
        single_sentence = re.split('[^а-я]', text[sentence])
        #print(single_sentence)
        for word in single_sentence:
            for i in range(len(uniq_tokens)):
                if word == uniq_tokens[i]:
                    #print(word, i)
                    matrix[sentence, i] = 1

    return matrix, uniq_tokens

# %%
# function for text filtration and lemmatization of inputed text
def filtration(text):
  text = text.lower()
  text = ''.join(m.lemmatize(text))
  text = re.sub(r'[^а-я\']', ' ', text)
  text = text.split()
  print('ok')
  return ' '.join(text)

# %%
# function for encoding of inputed text with unique tokens to compare it with matrix
def sentence_encoder(text, uniq_tokens):
    text = filtration(text)
    #print(text)
    if len(text) > len(uniq_tokens):
        text = text[:len(uniq_tokens)]
    encoded = np.zeros(len(uniq_tokens))
    for word in text.split():
        for i in range(len(uniq_tokens)):
            if word == uniq_tokens[i]:
                print(word, i)
                encoded[i] = 1
    return encoded, text

# %%
# function for counting cousine distance and define closest sentences from text and index or closest sentence
def nearest_phrase(encoded_input, matrix):

    index_list = []  # list for indexes
    distance_list = []  # list for cousine distances
    for i in range(matrix.shape[0]):  # cycle for compare encoded inputed phrase with phrases from file
         index_list.append(i)   
         distance_list.append(scipy.spatial.distance.cosine(encoded_input, matrix[i,:]))    # counting of cousine distance

    # table with results
    distance_table = pd.DataFrame([index_list, distance_list], index=['index', 'distance'])
    distance_table = distance_table.T
    #print(np.argmin(distance_table['distance']))
    needable_index = np.argmin(distance_table['distance'])
    distance_table = distance_table.sort_values(by='distance', ascending=True)
    #print(distance_table.head(5))
    
    return distance_table, needable_index

# %%
matrix_a, uniq_tokens = matrix_by_text(text)
# Out:
# Number of strings in text: 222
# Number of tokens in text: 2214
# Number of unique tokens in text: 797
# Matrix shape: (222, 797)

# %%
input_text = input()
print('Inputed text:', input_text)
# Out:
# Inputed text: мудрость труд Солнце 12 труды человек

# %%
enc_input, phrase = sentence_encoder(input_text, uniq_tokens)
print('Processed inputed text:', phrase)
# Out:
# ok
# мудрость 69
# труд 11
# солнце 14
# труд 11
# человек 9
# Processed inputed text: мудрость труд солнце труд человек

# %%
distance_table, needable_index = nearest_phrase(enc_input, matrix_a)
print()
print('5 closest phrase from text:')
print()
for i in distance_table['index'][:5]:
    print(text_df['original'][i], round(distance_table['distance'][i],2))
# Out:
# 5 closest phrase from text:
#
# 1:3 что пользы человеку от всех трудов его, которыми трудится он под солнцем? 0.43
# 2:18 и возненавидел я весь труд мой, которым трудился под солнцем, потому что должен оставить его человеку, который будет после меня. 0.5
# 2:22 ибо что будет иметь человек от всего труда своего и заботы сердца своего, что трудится он под солнцем? 0.5
# 9:13 вот еще какую мудрость видел я под солнцем, и она показалась мне важною: 0.55
# 7:11 хороша мудрость с наследством, и особенно для видящих солнце: 0.59
